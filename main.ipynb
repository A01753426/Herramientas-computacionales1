# %% [markdown]
# # Streaming Netflix Data
# ---
# ## Detailed information about Films and TV shows available on Netflix as of 2021
#
# It contains 8,807 Records and 12 attributes, covering a wide range of information such as title, type, director, cast, country, release year, rating, duration, and Category.
#
# ## Procesos para analizar el archivo
# 1. para hacer listados
# 2. hacer revision de los tipos de datos
# 3. existencia de datos nulos o duplicados
# 4. eliminar inconsistencias
# 5. llevar acabo analisis apoyado de gráficas
#
# ## Tomar en cuenta

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
# df.head()= primeras 5 filas
#df.head(n)=primeras n filas 
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df["rating"]
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
df[['release_year', 'rating', 'duration', 'listed_in']]
# Out:
#       release_year rating   duration  \
# 0             2020  PG-13     90 min
# 1             2021  TV-MA  2 Seasons
# 2             2021  TV-MA   1 Season
# 3             2021  TV-MA   1 Season
# 4             2021  TV-MA  2 Seasons
# ...            ...    ...        ...
# 8802          2007      R    158 min
# 8803          2018  TV-Y7  2 Seasons
# 8804          2009      R     88 min
# 8805          2006     PG     88 min
# 8806          2015  TV-14    111 min
#
#                                               listed_in
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# ...

# %%
print(f"Promedio:{df["release_year"].mean()}")
print(f"Mediana:{df["release_year"].median()}")
print(f"Moda:{df["release_year"].mode()}")
print(f"Desviación Estandar:{df["release_year"].std()}")
print(f"Varianza:{df["release_year"].var()}")
print(f"Mínimo:{df["release_year"].min()}")
print(f"Máximo:{df["release_year"].max()}")
print(f"Q1:{df["release_year"].quantile(0.25)}")
print(f"Q2:{df["release_year"].quantile(0.50)}")
print(f"Q3:{df["release_year"].quantile(0.75)}")
# Out:
# Promedio:2014.1801975701146
# Mediana:2017.0
# Moda:0    2018
# Name: release_year, dtype: int64
# Desviación Estandar:8.819312130833966
# Varianza:77.78026646107516
# Mínimo:1925
# Máximo:2021
# Q1:2013.0
# Q2:2017.0
# Q3:2019.0

# %%
#Caja y bigotes (box y wiskers) -> Gráfica de cajas (boxplots)
df["release_year"].plot.box()
# Out:
# <Axes: >

# %%
df["release_year"].dtype
# Out:
# dtype('int64')

# %%
columnas_númericas = []
columnas_no_númericas = []
for col in df.columns:
    if df[col].dtype =="object":
        columnas_no_númericas.append(col)
    else:
        columnas_númericas.append(col)
print (f"Columnas numéricas: {columnas_númericas}")
print (f"Columnas no numéricas: {columnas_no_númericas}")
# Out:
# Columnas numéricas: ['show_id', 'release_year']
# Columnas no numéricas: ['type', 'title', 'director', 'cast', 'country', 'date_added', 'rating', 'duration', 'listed_in', 'description']

# %%
df["show_id"] = pd.to_numeric(df["show_id"].str.replace("s","0"))

# %%
for col in columnas_númericas :
    df[col].plot.box(title=col)
    plt.show()

# %%
for col in columnas_númericas :
    df[col].plot.kde(title=col)
    plt.show()

# %%
df.head()
# Out:
#    show_id     type                  title         director  \
# 0        1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1        2  TV Show          Blood & Water              NaN
# 2        3  TV Show              Ganglands  Julien Leclercq
# 3        4  TV Show  Jailbirds New Orleans              NaN
# 4        5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.plot.bar(x="release_year", y="show_id")
# Out:
# <Axes: xlabel='release_year'>

# %%
df.groupby("release_year")["show_id"].mean().reset_index().nlargest(5,"show_id")
# Out:
#    release_year      show_id
# 2          1943  8721.666667
# 6          1947  8588.000000
# 3          1944  8499.333333
# 8          1955  8100.666667
# 1          1942  7998.500000

# %%
df.groupby("release_year")["show_id"].mean().reset_index().nlargest(5,"show_id").plot.bar(x="release_year", y="show_id")
# Out:
# <Axes: xlabel='release_year'>

# %%
df["release_year"].value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64

# %%
df["release_year"].value_counts().nlargest(74).plot.pie(autopct="%.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["release_year"].value_counts(bins=10)
# Out:
# (2011.4, 2021.0]      7093
# (2001.8, 2011.4]      1107
# (1992.2, 2001.8]       294
# (1982.6, 1992.2]       150
# (1973.0, 1982.6]        89
# (1963.4, 1973.0]        37
# (1953.8, 1963.4]        21
# (1934.6, 1944.2]         8
# (1944.2, 1953.8]         7
# (1924.903, 1934.6]       1
# Name: count, dtype: int64

# %%
df["release_year"].plot.hist(bins=10, title="Histograma de release_year")
# Out:
# <Axes: title={'center': 'Histograma de release_year'}, ylabel='Frequency'>

# %%
df["director"].unique()
# Out:
# array(['Kirsten Johnson', nan, 'Julien Leclercq', ..., 'Majid Al Ansari',
#        'Peter Hewitt', 'Mozez Singh'], shape=(4529,), dtype=object)

# %%
df.loc[df["director"]== "Peter Hewitt"]
# Out:
#       show_id   type title      director  \
# 8805     8806  Movie  Zoom  Peter Hewitt
#
#                                                    cast        country  \
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
#
#             date_added  release_year rating duration  \
# 8805  January 11, 2020          2006     PG   88 min
#
#                                listed_in  \
# 8805  Children & Family Movies, Comedies
#
#                                             description
# 8805  Dragged from civilian life, a former superhero...

# %%
df.loc[df["show_id"] <= 50]
# Out:
#     show_id     type                                              title  \
# 0         1    Movie                               Dick Johnson Is Dead
# 1         2  TV Show                                      Blood & Water
# 2         3  TV Show                                          Ganglands
# 3         4  TV Show                              Jailbirds New Orleans
# 4         5  TV Show                                       Kota Factory
# 5         6  TV Show                                      Midnight Mass
# 6         7    Movie                   My Little Pony: A New Generation
# 7         8    Movie                                            Sankofa
# 8         9  TV Show                      The Great British Baking Show
# 9        10    Movie                                       The Starling
# 10       11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11       12  TV Show                                   Bangkok Breaking
# ...

# %%
# and -> &
# or -> |
# not -> ~
# filas donde OPEN estuvo abajo  de 20 y Close estuvo arriba de 30
df.loc[(df["show_id"] < 20) & (df["release_year"] > 2000), ["title", "type", "release_year"]]
# Out:
#                                                 title     type  release_year
# 0                                Dick Johnson Is Dead    Movie          2020
# 1                                       Blood & Water  TV Show          2021
# 2                                           Ganglands  TV Show          2021
# 3                               Jailbirds New Orleans  TV Show          2021
# 4                                        Kota Factory  TV Show          2021
# 5                                       Midnight Mass  TV Show          2021
# 6                    My Little Pony: A New Generation    Movie          2021
# 8                       The Great British Baking Show  TV Show          2021
# 9                                        The Starling    Movie          2021
# 10                Vendetta: Truth, Lies and The Mafia  TV Show          2021
# 11                                   Bangkok Breaking  TV Show          2021
# ...

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
numerical_columns = []
categorical_columns = []
for column in df.columns:
    if df[column].dtype == 'object':
        categorical_columns.append(column)
    else:
        numerical_columns.append(column)

# %%
preprocessor = ColumnTransformer([
    ("num", StandardScaler(), numerical_columns),
    ("cat", OneHotEncoder(), categorical_columns)
])

# %%
X = preprocessor.fit_transform(df)

# %%
inertias = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)
    diff = inertias[-2] - inertias[-1] if k > 1 else 0
    print(f'K={k}, Inercia = {kmeans.inertia_:,.6f} - Diferencia = {diff:,.6f}')
# Out:
# K=1, Inercia = 96,083.563415 - Diferencia = 0.000000
# K=2, Inercia = 89,436.850046 - Diferencia = 6,646.713369
# K=3, Inercia = 88,509.427995 - Diferencia = 927.422051
# K=4, Inercia = 83,108.899016 - Diferencia = 5,400.528980
# K=5, Inercia = 81,749.693363 - Diferencia = 1,359.205653
# K=6, Inercia = 80,500.375891 - Diferencia = 1,249.317472
# K=7, Inercia = 79,495.944235 - Diferencia = 1,004.431656
# K=8, Inercia = 78,840.524011 - Diferencia = 655.420224
# K=9, Inercia = 78,274.705413 - Diferencia = 565.818598
# K=10, Inercia = 77,853.420996 - Diferencia = 421.284417

# %%
sns.lineplot(x=range(1, 11), y=inertias, marker="o")
plt.xlabel("Número de clusters (k)")
plt.ylabel("Inercia (SSE - Suma de errores al cuadrado)")
plt.title("Método del codo para determinar el número óptimo de clusters")
plt.xticks(range(1, 11))
plt.grid()
plt.show()

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(X)
df["Cluster"] = kmeans.labels_
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=df["Cluster"])
plt.title("Visualización de clusters con PCA")
plt.show()

# %%
df["Cluster"].value_counts()
# Out:
# Cluster
# 1    4721
# 2    1491
# 3    1159
# 0    1140
# 4     296
# Name: count, dtype: int64

# %%
df[numerical_columns + ["Cluster"]].groupby("Cluster").mean()
# Out:
#          release_year
# Cluster
# 0         2018.064912
# 1         2017.075196
# 2         2016.378940
# 3         2004.893874
# 4         1978.331081

# %%
df[categorical_columns + ["Cluster"]].groupby("Cluster").agg(lambda x: x.mode()[0])
# Out:
#         show_id     type                title                director  \
# Cluster
# 0          s100  TV Show             #blackAF             Shin Won-ho
# 1            s1    Movie               #Alive  Raúl Campos, Jan Suter
# 2         s1005  TV Show   100 Days My Prince     Alastair Fothergill
# 3         s1016    Movie          10,000 B.C.       Toshiya Shinohara
# 4         s1056    Movie  300 Miles to Heaven         Youssef Chahine
#
#                                                       cast        country  \
# Cluster
# 0                                           Dave Chappelle  United States
# 1        Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...  United States
# 2                                       David Attenborough  United States
# 3                                               Bill Hicks  United States
# 4                                              Sam Kinison  United States
#
#                 date_added rating  duration  \
# Cluster
# ...

# %%
sns.barplot(df, x="Cluster", y="release_year", estimator="mean")
# Out:
# <Axes: xlabel='Cluster', ylabel='release_year'>

# %%
sns.scatterplot(df, x="release_year", y="rating", hue="Cluster")
# Out:
# <Axes: xlabel='release_year', ylabel='rating'>
